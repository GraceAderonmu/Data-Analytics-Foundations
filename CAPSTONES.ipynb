# %% [markdown]
# <a href="https://colab.research.google.com/github/GraceAderonmu/Data-Analytics-Foundations/blob/main/CAPSTONES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importing all my libraries

# %%
import pandas as pd
import numpy as py
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# My project is from DYCD: Popular Baby Names by Sex and Ethnic Group

# %%
babynamedata= pd.read_csv('/content/Popular_Baby_Names.csv')
babynamedata
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 49504           2018  FEMALE  BLACK NON HISPANIC               Nala     10
# 49505           2018  FEMALE  BLACK NON HISPANIC            Royalty     10
# 49506           2018  FEMALE  BLACK NON HISPANIC            Sariyah     10
# 49507           2018  FEMALE  BLACK NON HISPANIC             Simone     10
# 49508           2018  FEMALE  BLACK NON HISPANIC              Zahra     10
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# ...

# %% [markdown]
# Understanding/Analyzing my data using decribe//head/tail function

# %%
babynamedata.head(10)
# Out:
#    Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# 0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC                GIA     21    67
# 2           2011  FEMALE  HISPANIC             GIANNA     49    42
# 3           2011  FEMALE  HISPANIC            GISELLE     38    51
# 4           2011  FEMALE  HISPANIC              GRACE     36    53
# 5           2011  FEMALE  HISPANIC          GUADALUPE     26    62
# 6           2011  FEMALE  HISPANIC             HAILEY    126     8
# 7           2011  FEMALE  HISPANIC              HALEY     14    74
# 8           2011  FEMALE  HISPANIC             HANNAH     17    71
# 9           2011  FEMALE  HISPANIC             HAYLEE     17    71

# %%
babynamedata.tail(10)
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 49499           2018  FEMALE  BLACK NON HISPANIC            Madisyn     10
# 49500           2018  FEMALE  BLACK NON HISPANIC             Mariah     10
# 49501           2018  FEMALE  BLACK NON HISPANIC           McKenzie     10
# 49502           2018  FEMALE  BLACK NON HISPANIC            Melanie     10
# 49503           2018  FEMALE  BLACK NON HISPANIC              Milan     10
# 49504           2018  FEMALE  BLACK NON HISPANIC               Nala     10
# 49505           2018  FEMALE  BLACK NON HISPANIC            Royalty     10
# 49506           2018  FEMALE  BLACK NON HISPANIC            Sariyah     10
# 49507           2018  FEMALE  BLACK NON HISPANIC             Simone     10
# 49508           2018  FEMALE  BLACK NON HISPANIC              Zahra     10
#
#        Rank
# 49499    40
# 49500    40
# 49501    40
# 49502    40
# 49503    40
# 49504    40
# 49505    40
# 49506    40
# 49507    40
# ...

# %%
babynamedata.describe()
# Out:
#        Year of Birth         Count          Rank
# count   49509.000000  49509.000000  49509.000000
# mean     2013.407421     33.839807     57.032418
# std         2.145505     38.877785     25.504754
# min      2011.000000     10.000000      1.000000
# 25%      2012.000000     13.000000     38.000000
# 50%      2013.000000     20.000000     58.000000
# 75%      2014.000000     36.000000     78.000000
# max      2019.000000    426.000000    102.000000

# %%
babynamedata.max()
# Out:
# Year of Birth                       2019
# Gender                              MALE
# Ethnicity             WHITE NON HISPANIC
# Child's First Name                Zyaire
# Count                                426
# Rank                                 102
# dtype: object

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
babynamedata.head(85)
# Out:
#     Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# 0            2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1            2011  FEMALE  HISPANIC                GIA     21    67
# 2            2011  FEMALE  HISPANIC             GIANNA     49    42
# 3            2011  FEMALE  HISPANIC            GISELLE     38    51
# 4            2011  FEMALE  HISPANIC              GRACE     36    53
# 5            2011  FEMALE  HISPANIC          GUADALUPE     26    62
# 6            2011  FEMALE  HISPANIC             HAILEY    126     8
# 7            2011  FEMALE  HISPANIC              HALEY     14    74
# 8            2011  FEMALE  HISPANIC             HANNAH     17    71
# 9            2011  FEMALE  HISPANIC             HAYLEE     17    71
# 10           2011  FEMALE  HISPANIC             HAYLEY     13    75
# 11           2011  FEMALE  HISPANIC              HAZEL     10    78
# 12           2011  FEMALE  HISPANIC             HEAVEN     15    73
# ...

# %%
babynamedata.columns
# Out:
# Index(['Year of Birth', 'Gender', 'Ethnicity', 'Child's First Name', 'Count',
#        'Rank'],
#       dtype='object')

# %%
babynamedata[["Year of Birth","Ethnicity","Child's First Name"]]
# Out:
#        Year of Birth           Ethnicity Child's First Name
# 0               2011            HISPANIC          GERALDINE
# 1               2011            HISPANIC                GIA
# 2               2011            HISPANIC             GIANNA
# 3               2011            HISPANIC            GISELLE
# 4               2011            HISPANIC              GRACE
# ...              ...                 ...                ...
# 49504           2018  BLACK NON HISPANIC               Nala
# 49505           2018  BLACK NON HISPANIC            Royalty
# 49506           2018  BLACK NON HISPANIC            Sariyah
# 49507           2018  BLACK NON HISPANIC             Simone
# 49508           2018  BLACK NON HISPANIC              Zahra
#
# [49509 rows x 3 columns]

# %%
babynamedata[["Child's First Name","Count"]]
# Out:
#       Child's First Name  Count
# 0              GERALDINE     13
# 1                    GIA     21
# 2                 GIANNA     49
# 3                GISELLE     38
# 4                  GRACE     36
# ...                  ...    ...
# 49504               Nala     10
# 49505            Royalty     10
# 49506            Sariyah     10
# 49507             Simone     10
# 49508              Zahra     10
#
# [49509 rows x 2 columns]

# %% [markdown]
# Looking for Nan/Null Values

# %%
babynamedata.isnull()
# Out:
#        Year of Birth  Gender  Ethnicity  Child's First Name  Count   Rank
# 0              False   False      False               False  False  False
# 1              False   False      False               False  False  False
# 2              False   False      False               False  False  False
# 3              False   False      False               False  False  False
# 4              False   False      False               False  False  False
# ...              ...     ...        ...                 ...    ...    ...
# 49504          False   False      False               False  False  False
# 49505          False   False      False               False  False  False
# 49506          False   False      False               False  False  False
# 49507          False   False      False               False  False  False
# 49508          False   False      False               False  False  False
#
# [49509 rows x 6 columns]

# %% [markdown]
# Here I am looking for the most popular name&ethnicity in this dataset

# %%
babynamedata[["Child's First Name","Count","Year of Birth", "Gender","Ethnicity"]].max()
# Out:
# Child's First Name                Zyaire
# Count                                426
# Year of Birth                       2019
# Gender                              MALE
# Ethnicity             WHITE NON HISPANIC
# dtype: object

# %% [markdown]
# looking at data of white non hispanic demographic in this dataset, since they return the most results in this dataframe

# %%
babynamedata[babynamedata['Ethnicity'] == 'WHITE NON HISPANIC'].sort_values(by=['Year of Birth'])
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 206             2011  FEMALE  WHITE NON HISPANIC            ABIGAIL    103
# 17817           2011    MALE  WHITE NON HISPANIC             SHULEM     42
# 17818           2011    MALE  WHITE NON HISPANIC             SIDNEY     10
# 17819           2011    MALE  WHITE NON HISPANIC              SILAS     10
# 17820           2011    MALE  WHITE NON HISPANIC             SIMCHA     32
# ...              ...     ...                 ...                ...    ...
# 38900           2019  FEMALE  WHITE NON HISPANIC              Ruchy     27
# 38899           2019  FEMALE  WHITE NON HISPANIC              Henny     27
# 38898           2019  FEMALE  WHITE NON HISPANIC            Cecilia     27
# 38907           2019  FEMALE  WHITE NON HISPANIC             Skylar     25
# 38408           2019    MALE  WHITE NON HISPANIC             Joseph    233
#
#        Rank
# 206      19
# 17817    65
# 17818    97
# 17819    97
# ...

# %%
babynamedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49509 entries, 0 to 49508
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year of Birth       49509 non-null  int64
#  1   Gender              49509 non-null  object
#  2   Ethnicity           49509 non-null  object
#  3   Child's First Name  49509 non-null  object
#  4   Count               49509 non-null  int64
#  5   Rank                49509 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 2.3+ MB

# %% [markdown]
# Data Transformation - converting columns to different data types

# %%
babynamedata[['Year of Birth','Count']] = babynamedata[['Year of Birth','Count']].astype('int64')
print(babynamedata.dtypes)
# Out:
# Year of Birth          int64
# Gender                object
# Ethnicity             object
# Child's First Name    object
# Count                  int64
# Rank                   int64
# dtype: object

# %%
Ethnicity.dtypes
# Out:
# Year of Birth          int64
# Gender                object
# Ethnicity             object
# Child's First Name    object
# Count                  int64
# Rank                   int64
# dtype: object

# %%
babynamedata.groupby('Ethnicity')['Gender'].count()
# Out:
# Ethnicity
# ASIAN AND PACI                 1767
# ASIAN AND PACIFIC ISLANDER     6799
# BLACK NON HISP                 1740
# BLACK NON HISPANIC             7213
# HISPANIC                      14530
# WHITE NON HISP                 3441
# WHITE NON HISPANIC            14019
# Name: Gender, dtype: int64

# %%
Ethnicity.groupby('Ethnicity')['Year of Birth'].count()
# Out:
# Ethnicity
# WHITE NON HISPANIC    14019
# Name: Year of Birth, dtype: int64

# %% [markdown]
# Statistical analysis that supports my data- looking for a comparison between males vs females

# %%
Ethnicity= babynamedata[babynamedata['Ethnicity'] == 'WHITE NON HISPANIC']
sns.displot(data=Ethnicity, x="Year of Birth", hue="Gender", multiple="dodge",binwidth=12, height=10, facet_kws=dict(margin_titles=True))

# %% [markdown]
# Comparing with another ethnicity in the dataframe

# %%
Ethnicity1 = babynamedata[babynamedata['Ethnicity'] == 'BLACK NON HISPANIC']
Ethnicity1
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 698             2011    MALE  BLACK NON HISPANIC              AARON     53
# 699             2011    MALE  BLACK NON HISPANIC             ABDOUL     16
# 700             2011    MALE  BLACK NON HISPANIC          ABDOULAYE     13
# 701             2011    MALE  BLACK NON HISPANIC               ADAM     28
# 702             2011    MALE  BLACK NON HISPANIC               ADEN     19
# ...              ...     ...                 ...                ...    ...
# 49504           2018  FEMALE  BLACK NON HISPANIC               Nala     10
# 49505           2018  FEMALE  BLACK NON HISPANIC            Royalty     10
# 49506           2018  FEMALE  BLACK NON HISPANIC            Sariyah     10
# 49507           2018  FEMALE  BLACK NON HISPANIC             Simone     10
# 49508           2018  FEMALE  BLACK NON HISPANIC              Zahra     10
#
#        Rank
# 698      28
# 699      58
# 700      61
# 701      46
# ...

# %%
sns.displot(data=Ethnicity1, x="Year of Birth", hue="Gender", multiple="dodge", binwidth=12, height=10, facet_kws=dict(margin_titles=True))

# %%
seldata = pd.concat([Ethnicity,Ethnicity1], ignore_index=True)
seldata
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE  WHITE NON HISPANIC            ABIGAIL    103
# 1               2011  FEMALE  WHITE NON HISPANIC            ADDISON     19
# 2               2011  FEMALE  WHITE NON HISPANIC              ADELE     22
# 3               2011  FEMALE  WHITE NON HISPANIC            ADELINE     12
# 4               2011  FEMALE  WHITE NON HISPANIC              ADINA     19
# ...              ...     ...                 ...                ...    ...
# 21227           2018  FEMALE  BLACK NON HISPANIC               Nala     10
# 21228           2018  FEMALE  BLACK NON HISPANIC            Royalty     10
# 21229           2018  FEMALE  BLACK NON HISPANIC            Sariyah     10
# 21230           2018  FEMALE  BLACK NON HISPANIC             Simone     10
# 21231           2018  FEMALE  BLACK NON HISPANIC              Zahra     10
#
#        Rank
# 0        19
# 1        72
# 2        69
# 3        79
# ...

# %%
seldata.sort_values(by=['Year of Birth'])['Ethnicity'].value_counts()
# Out:
# WHITE NON HISPANIC    14019
# BLACK NON HISPANIC     7213
# Name: Ethnicity, dtype: int64

# %%
sns.displot(data=seldata, x= "Year of Birth" ,hue="Gender", multiple="fill", binwidth=12, height=10, facet_kws=dict(margin_titles=True))
