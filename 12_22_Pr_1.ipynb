# %% [markdown]
# <a href="https://colab.research.google.com/github/GraceAderonmu/Data-Analytics-Foundations/blob/main/12_22_Pr_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %% [markdown]
# analyzing given data

# %%
df.tail()
# Out:
#        School DBN           School Name School Level  \
# 212326     84X717  Icahn Charter School          K-8
# 212327     84X717  Icahn Charter School          K-8
# 212328     84X717  Icahn Charter School          K-8
# 212329     84X717  Icahn Charter School          K-8
# 212330     84X717  Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# ...

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
df.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
df.shape
# Out:
# (212331, 15)

# %%
df.max()
# Out:
# <ipython-input-7-4c1ddf8920ff>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()
# School DBN                                                      84X717
# School Name                    Young Women's Leadership School, Queens
# School Level                                          Secondary School
# Year                                                              2017
# Total Tested                                                      1729
# Mean Score                                                           s
# Number Scoring Below 65                                              s
# Percent Scoring Below 65                                             s
# Number Scoring 65 or Above                                           s
# Percent Scoring 65 or Above                                          s
# ...

# %%
df.min()
# Out:
# <ipython-input-8-c3612c624a3f>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.min()
# School DBN                                                                01M034
# School Name                    47 The American Sign Language and English Seco...
# School Level                                                          Elementary
# Year                                                                        2015
# Total Tested                                                                   1
# Mean Score                                                                    15
# Number Scoring Below 65                                                        0
# Percent Scoring Below 65                                                       0
# ...

# %% [markdown]
# finding missing values

# %%
df.isnull().count
# Out:
# <bound method DataFrame.count of         School DBN  School Name  School Level  Regents Exam   Year  \
# 0            False        False         False         False  False
# 1            False        False         False         False  False
# 2            False        False         False         False  False
# 3            False        False         False         False  False
# 4            False        False         False         False  False
# ...            ...          ...           ...           ...    ...
# 212326       False        False         False         False  False
# 212327       False        False         False         False  False
# 212328       False        False         False         False  False
# 212329       False        False         False         False  False
# 212330       False        False         False         False  False
#
#         Total Tested  Mean Score  Number Scoring Below 65  \
# 0              False       False                    False
# ...

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
df_80orabove=df[['School Name', 'School Level', 'Year', 'Percent Scoring 80 or Above']]
df_80orabove
# Out:
#                            School Name School Level  Year  \
# 0       P.S. 034 Franklin D. Roosevelt          K-8  2017
# 1       P.S. 034 Franklin D. Roosevelt          K-8  2015
# 2       P.S. 034 Franklin D. Roosevelt          K-8  2016
# 3               P.S. 140 Nathan Straus          K-8  2016
# 4               P.S. 140 Nathan Straus          K-8  2017
# ...                                ...          ...   ...
# 212326            Icahn Charter School          K-8  2016
# 212327            Icahn Charter School          K-8  2016
# 212328            Icahn Charter School          K-8  2017
# 212329            Icahn Charter School          K-8  2017
# 212330            Icahn Charter School          K-8  2015
#
#        Percent Scoring 80 or Above
# 0                                s
# 1                             43.8
# 2                             22.2
# 3                                s
# 4                                s
# ...                            ...
# ...

# %%
df_80orabove1=df[['School Name', 'Total Tested', 'Year']]
df_80orabove1
# Out:
#                            School Name  Total Tested  Year
# 0       P.S. 034 Franklin D. Roosevelt             4  2017
# 1       P.S. 034 Franklin D. Roosevelt            16  2015
# 2       P.S. 034 Franklin D. Roosevelt             9  2016
# 3               P.S. 140 Nathan Straus             3  2016
# 4               P.S. 140 Nathan Straus             2  2017
# ...                                ...           ...   ...
# 212326            Icahn Charter School             8  2016
# 212327            Icahn Charter School             5  2016
# 212328            Icahn Charter School             6  2017
# 212329            Icahn Charter School             4  2017
# 212330            Icahn Charter School             1  2015
#
# [212331 rows x 3 columns]

# %%
df_totaltestedbyyear=df[['Year','Total Tested','School Name', 'School Level']]
df_totaltestedbyyear
# Out:
#         Year  Total Tested                     School Name School Level
# 0       2017             4  P.S. 034 Franklin D. Roosevelt          K-8
# 1       2015            16  P.S. 034 Franklin D. Roosevelt          K-8
# 2       2016             9  P.S. 034 Franklin D. Roosevelt          K-8
# 3       2016             3          P.S. 140 Nathan Straus          K-8
# 4       2017             2          P.S. 140 Nathan Straus          K-8
# ...      ...           ...                             ...          ...
# 212326  2016             8            Icahn Charter School          K-8
# 212327  2016             5            Icahn Charter School          K-8
# 212328  2017             6            Icahn Charter School          K-8
# 212329  2017             4            Icahn Charter School          K-8
# 212330  2015             1            Icahn Charter School          K-8
#
# [212331 rows x 4 columns]

# %%
df_totaltestedbyyear2017=df[['Total Tested','School Name', 'School Level']]
df_totaltestedbyyear2017
# Out:
#         Total Tested                     School Name School Level
# 0                  4  P.S. 034 Franklin D. Roosevelt          K-8
# 1                 16  P.S. 034 Franklin D. Roosevelt          K-8
# 2                  9  P.S. 034 Franklin D. Roosevelt          K-8
# 3                  3          P.S. 140 Nathan Straus          K-8
# 4                  2          P.S. 140 Nathan Straus          K-8
# ...              ...                             ...          ...
# 212326             8            Icahn Charter School          K-8
# 212327             5            Icahn Charter School          K-8
# 212328             6            Icahn Charter School          K-8
# 212329             4            Icahn Charter School          K-8
# 212330             1            Icahn Charter School          K-8
#
# [212331 rows x 3 columns]

# %% [markdown]
# # Define a dictionary containing employee data
# data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
#         'Age':[27, 24, 22, 32],
#         'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
#         'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
#
# # Convert the dictionary into DataFrame
# df = pd.DataFrame(data)
#
# # select two columns
# df[['Name', 'Qualification']]

# %%
year={'Year':['2015,2016,2017'],'School Level':['K8'],'School Name':['Icahn Charter School','Franklin D. Roosevel']}
df=pd.DataFrame(year)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-347d878c284a> in <module>
#       1 year={'Year':['2015,2016,2017'],'School Level':['K8'],'School Name':['Icahn Charter School','Franklin D. Roosevel']}
# ----> 2 df=pd.DataFrame(year)
#       3
#       4
#       5
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %% [markdown]
# filtering columns by year

# %%
df2=df.query("Year =='2017'")
df2

# %%
df.query("Year == '2017'",inplace=True)
df

# %%
df.query("Year in ('2017','Py2017')")

# %%
df.loc[df['Year'] != 2017]
df

# %%
missing_values=['n/a','na','..']
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')
df

# %% [markdown]
# Dropping Null Values

# %%
df.dropna()
df

# %%
df.dropna(axis=1)
df

# %%
df.notna()

# %% [markdown]
# Dropping rows with n/a values

# %%
df.dropna(axis=0)
df

# %%
df.dropna(axis=0, how='all')

# %%
df.dropna (axis=0, how='any', thresh=None, subset=None, inplace=False)

# %% [markdown]
# Cleaning up our data?

# %%
df.info()

# %% [markdown]
# Group by syntax- school score

# %%
 df.groupby(['Regents Exam'])['Total Tested'].count()

# %%
 df.groupby(['Year'])['Total Tested'].min()

# %%
 df.groupby(['School Name'])['Year']
 df

# %%
 df.groupby(['School Name'])['Total Tested'].max()

# %%
 df.groupby(['Total Tested'])['Number Scoring 80 or Above']

# %% [markdown]
# importing seaborn for data visualization

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data.drop(["Team", "Weight"], axis = 1, inplace = True)

# %%
df.columns df= df.rename(columns={'Unnamed:O':'Vehicle Name'}) df
